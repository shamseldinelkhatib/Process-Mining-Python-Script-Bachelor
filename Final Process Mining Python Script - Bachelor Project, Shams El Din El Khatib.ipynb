# %%
from opyenxes.data_in.XUniversalParser import XUniversalParser
from opyenxes.extension.XExtensionParser import XExtensionParser
from opyenxes.extension.XExtensionManager import XExtensionManager
import opyenxes
from opyenxes.factory.XFactory import XFactory
from opyenxes.id.XIDFactory import XIDFactory
from opyenxes.data_out.XesXmlSerializer import XesXmlSerializer

import pandas as pd
import numpy as np

import time
from datetime import datetime
import datetime

import random

# DEFINE HELPER METHODS

def get_status(activity_name):
    if (activity_name =="register request"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Registering Request")
        

    elif (activity_name =="examine casually"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Casually Examining Request")
        

    elif (activity_name =="examine thoroughly"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Thoroughly Examining Request")
        

    elif (activity_name =="check ticket"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Checking Ticket")
        

    elif (activity_name =="decide"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Decision in Process")
        

    elif (activity_name =="reinitiate request"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Reinitiating Request")
        

    elif (activity_name =="reject request"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Request Rejected")
        

    elif (activity_name =="pay compensation"):
        status_attribute = XFactory.create_attribute_literal("attribute:status", "Compensation Paid")
        
    
    return status_attribute


def actualDates():
    df = pd.read_csv("C:/Users/Shams/Downloads/running-example.csv", sep=';')

    for a in range (len(df['timestamp'])):
        df['timestamp']= df['timestamp'].map(lambda x: x.lstrip('').rstrip('+00:10'))
    for i in range(len(df['timestamp'])):
        df.iloc[i, 2]+= ":00"
    df['timestamp'] = pd.to_datetime(df['timestamp'])

    print(type(df['timestamp']))
    selected_columns = df["timestamp"]
    timestamp_df = selected_columns.copy()

    return timestamp_df

# def taskDates():
#     df = pd.read_csv("C:/Users/Shams/Downloads/running-example.csv", sep=';')

#     for a in range (len(df['timestamp'])):
#         df['timestamp']= df['timestamp'].map(lambda x: x.lstrip('').rstrip('+00:10'))
#     for i in range(len(df['timestamp'])):
#         df.iloc[i, 2]+= ":00"
#     df['timestamp'] = pd.to_datetime(df['timestamp'])

# #     print(type(df['timestamp']))
    
#     selected_columns = df["timestamp"]
#     timestamp_df = selected_columns.copy()
    
#     return timestamp_df

def dateSequence(base, activity_flow):
    num = activity_flow
    date_list = []
#     base = actualDates()
    date_list = [base + datetime.timedelta(minutes= x, seconds= x) for x in range(num)]
    return date_list

# def dateSequence_index(a, i):
#     numdays = 4
#     date_list = []
#     base= pd.Series()
#     base.add(srt(log[a][i].get_attributes()["time:timestamp"])
#     ser_time= pd.Series()
#     ser_time=pd.to_datetime(base)
# #     ser_time.add(log[a][i].get_attributes()["time:timestamp"])
#     print("KHARA")
#     print(ser_time)
#     date_list = [ser_time[0] + datetime.timedelta(minutes= x, seconds= 20 + x) for x in range(numdays)]
#     return date_list

def create_sequence(activity_name, activity_flow, flag):
    if (activity_name == "register request"):
        activity_flow= ["Click on menu_button", "Click register_new_request_button"]

        mid_activities1= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
                           "select_field", "Click_fill_information_button"]

        mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
                           "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

        varying_activities2 = ["Type (*Customer_Name*) in name_field", "Type (*Customer_Address*) in address_field", 
                               "Import_Operation (*Financial_Statements*)", "Type (*Customer_rate*) in rate_field", 
                               "Type (*Requested_amount*) in amount field"]

        end_activities= [ "Click_complete_registration_button", "Type (#***) in employee_id_field", "Click_confirm_button"] 

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities2)):
                activity_flow.append(mid_activities2[i])

            for j in range(len(varying_activities2)):
                if(activity_flow[-1]==varying_activities2[j]):
                    random.shuffle(varying_activities2)
                else:
                    activity_flow.append(varying_activities2[j])
                    random.shuffle(varying_activities2)

            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])
        return activity_flow
    
    elif (activity_name == "examine casually"):
        activity_flow= ["Click on menu_button", "Click view_request_button"]

        mid_activities1= ["Type (*Customer_Name*) in name_field", "Type (*Customer_id*) in id_field", "Click search_for_request_button",
                           "select_field", "View (*Customer_Request*) window"]

        end_activities= ["Exit (*Customer_Request*) window"] 

        
        for i in range(len(mid_activities1)):
            activity_flow.append(mid_activities1[i])
        for a in range(len(end_activities)):
            activity_flow.append(end_activities[a])

                
        return activity_flow
            
    elif (activity_name == "examine thoroughly"):
        activity_flow= ["Click on menu_button", "Click view_request_button"]

        mid_activities1= ["Type (*Customer_Name*) in name_field", "Type (*Customer_id*) in id_field", 
                          "Click search_for_request_button", "select_field", "View (*Customer_Request*) window", "Click on inspect_button"]

#         mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
#                            "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

        varying_activities2 = ["Click on view_financial_trends_button", 
                               "Click on view_background_button"]

        end_activities= ["Exit (*Customer_Request*) window"]  

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])

            for j in range(len(varying_activities2)):
                if(activity_flow[-1]==varying_activities2[j]):
                    random.shuffle(varying_activities2)
                else:
                    activity_flow.append(varying_activities2[j])
                    random.shuffle(varying_activities2)

            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])
        return activity_flow
        

    elif (activity_name == "check ticket"):
        activity_flow= ["Click on menu_button", "Click view_request_button"]

        mid_activities1= ["Type (*Customer_Name*) in name_field", "Type (*Customer_id*) in id_field", 
                          "Click search_for_request_button", "select_field", "View (*Customer_Request*) window", 
                          "Click view_ticket_button", "Click on verify_ticket_button"]

#         mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
#                            "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

#         varying_activities2 = ["Click on verify_ticket_button"]

        end_activities= ["Exit (*Customer_Request*) window"]  

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        return activity_flow
    
    elif (activity_name == "decide"):
        activity_flow= ["Click on menu_button", "Click view_request_button"]

        mid_activities1= ["Type (*Customer_Name*) in name_field", "Type (*Customer_id*) in id_field", 
                          "Click search_for_request_button", "select_field", "View (*Customer_Request*) window"]

#         mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
#                            "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

#         varying_activities2 = ["Type (*Customer_Name*) in name_field", "Type (*Customer_Address*) in address_field", 
#                                "Import_Operation (*Financial_Statements*)", "Type (*Customer_rate*) in rate_field", 
#                                "Type (*Requested_amount*) in amount field"]

        end_activities= ["Click on submit_request_for_decision_button", "Exit (*Customer_Request*) window"]  

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])
                
        return activity_flow
    
    elif (activity_name == "reinitiate request"):
        activity_flow= ["Click on menu_button", "Click view_decision_request_button"]

        mid_activities1= ["View (*Customer_Request*) window", "Click on inspection_details_button", "Exit (*Inspection_details*) window"]

#         mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
#                            "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

#         varying_activities2 = ["Type (*Customer_Name*) in name_field", "Type (*Customer_Address*) in address_field", 
#                                "Import_Operation (*Financial_Statements*)", "Type (*Customer_rate*) in rate_field", 
#                                "Type (*Requested_amount*) in amount field"]

        end_activities= ["Click on reinitiate_request_button", "Type (#***) in employee_id_field", "Click_confirm_button", "Exit (*Customer_decision_request*) window", "Exit (*Customer_Request*) window"]

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])
                
        return activity_flow
    
    elif (activity_name == "pay compensation"):
        activity_flow= ["Click on menu_button", "Click view_decision_request_button"]

        mid_activities1= ["View (*Customer_Request*) window", "Click on inspection_details_button", "Exit (*Inspection_details*) window"]

#         mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
#                            "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

#         varying_activities2 = ["Type (*Customer_Name*) in name_field", "Type (*Customer_Address*) in address_field", 
#                                "Import_Operation (*Financial_Statements*)", "Type (*Customer_rate*) in rate_field", 
#                                "Type (*Requested_amount*) in amount field"]

        end_activities= ["Click on pay_compensation_button", "Type (#***) in employee_id_field", "Click_confirm_button", "Exit (*Customer_decision_request*) window", "Exit (*Customer_Request*) window"] 

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])
                
        return activity_flow
    
    
    elif (activity_name == "reject request"):
        activity_flow= ["Click on menu_button", "Click view_decision_request_button"]

        mid_activities1= ["View (*Customer_Request*) window", "Click on inspection_details_button", "Exit (*Inspection_details*) window"]

#         mid_activities2= ["Type (*Customer_Name*) in name_field", "Click search_for_existing_button",
#                            "Click register_new_customer_button", "Click create_new_customer_button"]

    #     start_varying_activities2 = ["Click create_new_customer_button"]

#         varying_activities2 = ["Type (*Customer_Name*) in name_field", "Type (*Customer_Address*) in address_field", 
#                                "Import_Operation (*Financial_Statements*)", "Type (*Customer_rate*) in rate_field", 
#                                "Type (*Requested_amount*) in amount field"]

        end_activities= ["Click on reject_request_button", "Type (#***) in employee_id_field", "Click_confirm_button", "Exit (*Customer_decision_request*) window", "Exit (*Customer_Request*) window"] 

        if(flag== True):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])

        elif(flag== False):
            for i in range(len(mid_activities1)):
                activity_flow.append(mid_activities1[i])
            for a in range(len(end_activities)):
                activity_flow.append(end_activities[a])
                
        return activity_flow
    
#     if(activity_flow[-1]=="check ticket"):
#         activity_flow.append(random.choice(examine_activity[:2]))
#     elif(activity_flow[-1]!= "check ticket"):
#         activity_flow.append(examine_activity[-1])
#     activity_flow.append(decision[0])
#     activity_flow.append(random.choice(end_activity))
#     if(activity_flow[-1]!= "reinitiate request"):
#         return activity_flow
#     elif(activity_flow[-1]== "reinitiate request"):
#         if("examine thoroughly" not in activity_flow):
#             activity_flow.append(examine_activity[1])
#             activity_flow.append(examine_activity[2])
#             activity_flow.append(decision[0])
#             activity_flow.append(random.choice(end_activity[1:]))
#         return activity_flow
    


# create_sequence(activity_flow, False)

def task_dates(activity_name):

    df = pd.read_csv("C:/Users/Shams/Downloads/running-example.csv", sep=';')
    selected_columns = df["timestamp"]
    timestamp_df = selected_columns.copy()
    for a in range (len(timestamp_df)):
        timestamp_df= timestamp_df.map(lambda x: x.lstrip('').rstrip('+00:10'))
        for i in range(len(timestamp_df)):
            timestamp_df[i]+= ":00"
    timestamp_df
    timestamp_list = timestamp_df.to_list()
    timestamp_list
    timestamp_df

    timestamp_df= timestamp_df.rename('new_timestamp')

    df['new_timestamp']= timestamp_df
    df
    # timestamp_df
    compare_df= df.loc[:, ['activity', 'timestamp', 'new_timestamp']]
    new_df= compare_df.copy()
    new_df

    df2= pd.DataFrame()
    df.insert(6, "task_timestamp", "", True)
    for i in range(len(new_df)):
        if(new_df.loc[i, 'activity']== activity_name):
            df.loc[df.index[i], 'task_timestamp'] = new_df.loc[i, 'new_timestamp']
    #         for j in range(6):
    #             value= new_df.loc[i, 'new_timestamp']
    #             df.insert(6, "task_timestamp" + str(j), value, True)

    # df['task_timestamp0'] = pd.to_datetime(df['task_timestamp0'])
    df['task_timestamp'] = pd.to_datetime(df['task_timestamp'])

    selected_columns = df['task_timestamp']
    task_timestamp_df = selected_columns.copy()
    # pd.to_datetime(df)
    # task_timestamp_df

    nan_value = float("NaN")

    task_timestamp_df.replace("", nan_value, inplace=True)

    task_timestamp_df.dropna(inplace=True)
    
    result= task_timestamp_df.reset_index(drop= True)
    
    print(result)
    
    return result

# FEEDING DATA INTO THE EVENT LOG

with open("G:/GUC/Fourth Year/Eighth Semester/ProM Event Logs/XES Data Sets/running-example.xes") as file:
    logs = XUniversalParser().parse(file)
    
log= logs[0]
print(type(log[0]))
print(type(log[0][0]))
print(len(log[0]))
print(len(log))
for trace in range(len(log)):
    print(log[trace].get_attributes()["concept:name"])
    compare= log[trace].get_attributes()["concept:name"].clone()
    comparestring= str(compare)
    if(comparestring== "1"):
        print("khara")
print(type(log[0]))
trace= log[0]
print(type(trace[0]))
event= trace[0]
print(trace.get_attributes())

for a in range(len(log)):
#     trace= log[a]
    compare= log[a].get_attributes()["concept:name"]
    comparestring= str(compare)
    if(comparestring == "1"):
#         event= trace[a]
        bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", "Customer")
        bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Markus Otto")
        request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", "MO1")
        rate_attribute = XFactory.create_attribute_discrete("attribute:rate", 5)
        amount_attribute = XFactory.create_attribute_continuous("attribute:amount", 15000)
                
        for i in range(len(log[a])):
            log[a][i].get_attributes()["attribute:bo_type"]= bo_type_attribute
            log[a][i].get_attributes()["attribute:name"]= bo_name_attribute
            log[a][i].get_attributes()["attribute:requestID"]= request_id_attribute
            log[a][i].get_attributes()["attribute:rate"]= rate_attribute
            log[a][i].get_attributes()["attribute:amount"]= amount_attribute
            log[a][i].get_attributes()["attribute:status"]= get_status(str(log[a][i].get_attributes()["concept:name"]))
#             log[a][i].get_attributes()["attribute:status"]= status_attribute

            
            
    elif(comparestring== "2"):
        
        bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", "Customer")
        bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Shams ElKhatib")
        request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", "SE2")
        rate_attribute = XFactory.create_attribute_discrete("attribute:rate", 1)
        amount_attribute = XFactory.create_attribute_continuous("attribute:amount", 30000)
                
        for i in range(len(log[a])):
            log[a][i].get_attributes()["attribute:bo_type"]= bo_type_attribute
            log[a][i].get_attributes()["attribute:name"]= bo_name_attribute
            log[a][i].get_attributes()["attribute:requestID"]= request_id_attribute
            log[a][i].get_attributes()["attribute:rate"]= rate_attribute
            log[a][i].get_attributes()["attribute:amount"]= amount_attribute
            log[a][i].get_attributes()["attribute:status"]= get_status(str(log[a][i].get_attributes()["concept:name"]))
            
    elif(comparestring== "3"):
        
        bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", "Customer")
        bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Farida ElHabrouk")
        request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", "FE3")
        rate_attribute = XFactory.create_attribute_discrete("attribute:rate", 2)
        amount_attribute = XFactory.create_attribute_continuous("attribute:amount", 25000)
                
        for i in range(len(log[a])):
            log[a][i].get_attributes()["attribute:bo_type"]= bo_type_attribute
            log[a][i].get_attributes()["attribute:name"]= bo_name_attribute
            log[a][i].get_attributes()["attribute:requestID"]= request_id_attribute
            log[a][i].get_attributes()["attribute:rate"]= rate_attribute
            log[a][i].get_attributes()["attribute:amount"]= amount_attribute
            log[a][i].get_attributes()["attribute:status"]= get_status(str(log[a][i].get_attributes()["concept:name"]))
            
    elif(comparestring== "4"):
        
        bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", "Customer")
        bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Mariam Ashraf")
        request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", "MA4")
        rate_attribute = XFactory.create_attribute_discrete("attribute:rate", 4)
        amount_attribute = XFactory.create_attribute_continuous("attribute:amount", 20000)
                
        for i in range(len(log[a])):
            log[a][i].get_attributes()["attribute:bo_type"]= bo_type_attribute
            log[a][i].get_attributes()["attribute:name"]= bo_name_attribute
            log[a][i].get_attributes()["attribute:requestID"]= request_id_attribute
            log[a][i].get_attributes()["attribute:rate"]= rate_attribute
            log[a][i].get_attributes()["attribute:amount"]= amount_attribute
            log[a][i].get_attributes()["attribute:status"]= get_status(str(log[a][i].get_attributes()["concept:name"]))
            
    elif(comparestring== "5"):
        
        bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", "Customer")
        bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Gamal Kassem")
        request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", "GK5")
        rate_attribute = XFactory.create_attribute_discrete("attribute:rate", 3)
        amount_attribute = XFactory.create_attribute_continuous("attribute:amount", 50000)
                
        for i in range(len(log[a])):
            log[a][i].get_attributes()["attribute:bo_type"]= bo_type_attribute
            log[a][i].get_attributes()["attribute:name"]= bo_name_attribute
            log[a][i].get_attributes()["attribute:requestID"]= request_id_attribute
            log[a][i].get_attributes()["attribute:rate"]= rate_attribute
            log[a][i].get_attributes()["attribute:amount"]= amount_attribute
            log[a][i].get_attributes()["attribute:status"]= get_status(str(log[a][i].get_attributes()["concept:name"]))
            
    elif(comparestring== "6"):
        
        bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", "Customer")
        bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Ali Kodera")
        request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", "AK6")
        rate_attribute = XFactory.create_attribute_discrete("attribute:rate", 1)
        amount_attribute = XFactory.create_attribute_continuous("attribute:amount", 45000)
                
        for i in range(len(log[a])):
            log[a][i].get_attributes()["attribute:bo_type"]= bo_type_attribute
            log[a][i].get_attributes()["attribute:name"]= bo_name_attribute
            log[a][i].get_attributes()["attribute:requestID"]= request_id_attribute
            log[a][i].get_attributes()["attribute:rate"]= rate_attribute
            log[a][i].get_attributes()["attribute:amount"]= amount_attribute
            log[a][i].get_attributes()["attribute:status"]= get_status(str(log[a][i].get_attributes()["concept:name"]))
            
#     elif(comparestring== "6"):
#         bo_name_attribute = XFactory.create_attribute_literal("attribute:name", "Gamal")
#         trace[a].get_attributes()["attribute:name"]= bo_name_attribute

def create_taskSteps(log, activity_name, taskTrace_name):
    counter=0
    counterdates=0
    # dates_list= dateSequence(task_dates())
    task_list= task_dates(activity_name)
    print(task_list)
    for a in range(len(log)):        
        for i in range(len(log[a])):
            if(str(log[a][i].get_attributes()["concept:name"])== activity_name):
                taskTrace = XFactory.create_trace()
                taskTrace_concept_name = XFactory.create_attribute_literal("steps:name", str(taskTrace_name) + str(counter))
                taskTrace_orig_concept_name= XFactory.create_attribute_literal("concept:name", str(taskTrace_name) + str(counter))
                counter+=1
#         taskTrace_name = XFactory.create_attribute_literal("steps:name", taskTrace_name)
                taskTrace_corresponding_trace = XFactory.create_attribute_literal("steps:corresponding_trace", log[a].get_attributes()["concept:name"])

                taskTrace_corresponding_event = XFactory.create_attribute_discrete("steps:corresponding_event", log[a][i].get_attributes()["@@index"])
                org_attribute = XFactory.create_attribute_literal("org:resource", log[a][i].get_attributes()["org:resource"])
                cost_attribute = XFactory.create_attribute_discrete("cost:total", log[a][i].get_attributes()["cost:total"])
                index_attribute = XFactory.create_attribute_discrete("@@index", int(str(log[a][i].get_attributes()["@@index"])) + random.randint(1,10))
                taskTrace_marker= XFactory.create_attribute_literal("steps:mark", "STEPS")
                #             dates_list= dateSequence_index(a, counter)
#                 taskTrace.get_attributes()["concept:name"]= taskTrace_concept_name
                taskTrace.get_attributes()["steps:name"] = taskTrace_concept_name
                taskTrace.get_attributes()["concept:name"] = taskTrace_orig_concept_name
                taskTrace.get_attributes()["steps:corresponding_trace"] = taskTrace_corresponding_trace
                taskTrace.get_attributes()["steps:corresponding_event"] = taskTrace_corresponding_event
                taskTrace.get_attributes()["steps:mark"] = taskTrace_marker
                activity_flow= []
                activity_flow= create_sequence(activity_name, activity_flow, bool(random. getrandbits(1)))
                print(activity_flow)

                
                if(a<len(task_list)):
                    dates_list= dateSequence(task_list[a], len(activity_flow))

                for j in range(len(activity_flow)):
                    taskEvent = XFactory.create_event()

                    org_resource= random.choice(["Pete", "Sue", "Mike", "Sara"])

                    cost= random.choice([50,100,200,400])
                    
                    activity_attribute = XFactory.create_attribute_literal("steps:taskname", activity_flow[j])
                    taskEvent.get_attributes()["concept:name"] = activity_attribute
                    
                    time_attribute = XFactory.create_attribute_timestamp("time:timestamp", dates_list[j])
                    taskEvent.get_attributes()["time:timestamp"] = time_attribute


                    taskEvent.get_attributes()["org:resource"] = org_attribute


                    taskEvent.get_attributes()["cost:total"] = cost_attribute


                    taskEvent.get_attributes()["@@index"] = index_attribute
                    
                    
                    bo_type_attribute = XFactory.create_attribute_literal("attribute:bo_type", log[a][i].get_attributes()["attribute:bo_type"])
                    bo_name_attribute = XFactory.create_attribute_literal("attribute:name", log[a][i].get_attributes()["attribute:name"])
                    request_id_attribute = XFactory.create_attribute_literal("attribute:requestID", log[a][i].get_attributes()["attribute:requestID"])
                    rate_attribute = XFactory.create_attribute_discrete("attribute:rate", log[a][i].get_attributes()["attribute:rate"])
                    amount_attribute = XFactory.create_attribute_continuous("attribute:amount", log[a][i].get_attributes()["attribute:amount"])
                    status_attribute = XFactory.create_attribute_literal("attribute:status", log[a][i].get_attributes()["attribute:status"])
                    
                    
                    taskEvent.get_attributes()["attribute:bo_type"]= bo_type_attribute
                    taskEvent.get_attributes()["attribute:name"]= bo_name_attribute
                    taskEvent.get_attributes()["attribute:requestID"]= request_id_attribute
                    taskEvent.get_attributes()["attribute:rate"]= rate_attribute
                    taskEvent.get_attributes()["attribute:amount"]= amount_attribute
                    taskEvent.get_attributes()["attribute:status"]= status_attribute
                    
                    
                    taskTrace.append(taskEvent)
                
                log.append(taskTrace)



create_taskSteps(log, "register request", "Register Request Steps")

create_taskSteps(log, "examine casually", "Examine Casually Steps")

create_taskSteps(log, "examine thoroughly", "Examine Thoroughly Steps")

create_taskSteps(log, "check ticket", "Check Ticket Steps")

create_taskSteps(log, "decide", "Decision Steps")

create_taskSteps(log, "reinitiate request", "Reinitiate Request Steps")

create_taskSteps(log, "pay compensation", "Pay Compensation Steps")

create_taskSteps(log, "reject request", "Reject Request Steps")





with open("G:/GUC/Fourth Year/Eighth Semester/ProM Event Logs/XES Data Sets/TRIAL.xes", "w") as file:
    XesXmlSerializer().serialize(log, file)
# Out:
# Unknown extension: gs://shams_xes/task_steps.xesext
# Unknown extension: gs://shams_xes/business_object.xesext
# <class 'opyenxes.model.XTrace.XTrace'>
# <class 'opyenxes.model.XEvent.XEvent'>
# 5
# 6
# 1
# khara
# 2
# 3
# 4
# 5
# 6
# <class 'opyenxes.model.XTrace.XTrace'>
# <class 'opyenxes.model.XEvent.XEvent'>
# {'concept:name': <opyenxes.model.XAttributeLiteral.XAttributeLiteral object at 0x0000023CDCF19D30>}
# 0   2010-12-30 14:32:00
# 1   2010-12-30 11:32:00
# 2   2010-12-30 11:02:00
# 3   2011-01-06 15:02:00
# 4   2011-01-06 09:02:00
# 5   2011-01-06 15:02:00
# Name: task_timestamp, dtype: datetime64[ns]
# 0   2010-12-30 14:32:00
# 1   2010-12-30 11:32:00
# 2   2010-12-30 11:02:00
# 3   2011-01-06 15:02:00
# 4   2011-01-06 09:02:00
# 5   2011-01-06 15:02:00
# Name: task_timestamp, dtype: datetime64[ns]
# ...
